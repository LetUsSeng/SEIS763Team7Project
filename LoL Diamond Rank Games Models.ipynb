# %% [markdown]
# # Reading in the data

# %%
import pandas as pd
lol_games = pd.read_csv("high_diamond_ranked_10min.csv")
lol_games
# Out:
#           gameId  blueWins  blueWardsPlaced  blueWardsDestroyed  \
# 0     4519157822         0               28                   2
# 1     4523371949         0               12                   1
# 2     4521474530         0               15                   0
# 3     4524384067         0               43                   1
# 4     4436033771         0               75                   4
# ...          ...       ...              ...                 ...
# 9874  4527873286         1               17                   2
# 9875  4527797466         1               54                   0
# 9876  4527713716         0               23                   1
# 9877  4527628313         0               14                   4
# 9878  4523772935         1               18                   0
#
#       blueFirstBlood  blueKills  blueDeaths  blueAssists  blueEliteMonsters  \
# 0                  1          9           6           11                  0
# 1                  0          5           5            5                  0
# 2                  0          7          11            4                  1
# 3                  0          4           5            5                  1
# 4                  0          6           6            6                  0
# ...              ...        ...         ...          ...                ...
# 9874               1          7           4            5                  1
# 9875               0          6           4            8                  1
# 9876               0          6           7            5                  0
# 9877               1          2           3            3                  1
# 9878               1          6           6            5                  0
#
#       blueDragons  ...  redTowersDestroyed  redTotalGold  redAvgLevel  \
# 0               0  ...                   0         16567          6.8
# 1               0  ...                   1         17620          6.8
# 2               1  ...                   0         17285          6.8
# 3               0  ...                   0         16478          7.0
# 4               0  ...                   0         17404          7.0
# ...           ...  ...                 ...           ...          ...
# 9874            1  ...                   0         15246          6.8
# 9875            1  ...                   0         15456          7.0
# 9876            0  ...                   0         18319          7.4
# 9877            1  ...                   0         15298          7.2
# 9878            0  ...                   0         15339          6.8
#
#       redTotalExperience  redTotalMinionsKilled  redTotalJungleMinionsKilled  \
# 0                  17047                    197                           55
# 1                  17438                    240                           52
# 2                  17254                    203                           28
# 3                  17961                    235                           47
# 4                  18313                    225                           67
# ...                  ...                    ...                          ...
# 9874               16498                    229                           34
# 9875               18367                    206                           56
# 9876               19909                    261                           60
# 9877               18314                    247                           40
# 9878               17379                    201                           46
#
#       redGoldDiff  redExperienceDiff  redCSPerMin  redGoldPerMin
# 0            -643                  8         19.7         1656.7
# 1            2908               1173         24.0         1762.0
# 2            1172               1033         20.3         1728.5
# 3            1321                  7         23.5         1647.8
# 4            1004               -230         22.5         1740.4
# ...           ...                ...          ...            ...
# 9874        -2519              -2469         22.9         1524.6
# 9875         -782               -888         20.6         1545.6
# 9876         2416               1877         26.1         1831.9
# 9877          839               1085         24.7         1529.8
# 9878         -927                 58         20.1         1533.9
#
# [9879 rows x 40 columns]

# %%
lol_games = lol_games.drop('gameId', axis=1)
lol_games
# Out:
#       blueWins  blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  \
# 0            0               28                   2               1
# 1            0               12                   1               0
# 2            0               15                   0               0
# 3            0               43                   1               0
# 4            0               75                   4               0
# ...        ...              ...                 ...             ...
# 9874         1               17                   2               1
# 9875         1               54                   0               0
# 9876         0               23                   1               0
# 9877         0               14                   4               1
# 9878         1               18                   0               1
#
#       blueKills  blueDeaths  blueAssists  blueEliteMonsters  blueDragons  \
# 0             9           6           11                  0            0
# 1             5           5            5                  0            0
# 2             7          11            4                  1            1
# 3             4           5            5                  1            0
# 4             6           6            6                  0            0
# ...         ...         ...          ...                ...          ...
# 9874          7           4            5                  1            1
# 9875          6           4            8                  1            1
# 9876          6           7            5                  0            0
# 9877          2           3            3                  1            1
# 9878          6           6            5                  0            0
#
#       blueHeralds  ...  redTowersDestroyed  redTotalGold  redAvgLevel  \
# 0               0  ...                   0         16567          6.8
# 1               0  ...                   1         17620          6.8
# 2               0  ...                   0         17285          6.8
# 3               1  ...                   0         16478          7.0
# 4               0  ...                   0         17404          7.0
# ...           ...  ...                 ...           ...          ...
# 9874            0  ...                   0         15246          6.8
# 9875            0  ...                   0         15456          7.0
# 9876            0  ...                   0         18319          7.4
# 9877            0  ...                   0         15298          7.2
# 9878            0  ...                   0         15339          6.8
#
#       redTotalExperience  redTotalMinionsKilled  redTotalJungleMinionsKilled  \
# 0                  17047                    197                           55
# 1                  17438                    240                           52
# 2                  17254                    203                           28
# 3                  17961                    235                           47
# 4                  18313                    225                           67
# ...                  ...                    ...                          ...
# 9874               16498                    229                           34
# 9875               18367                    206                           56
# 9876               19909                    261                           60
# 9877               18314                    247                           40
# 9878               17379                    201                           46
#
#       redGoldDiff  redExperienceDiff  redCSPerMin  redGoldPerMin
# 0            -643                  8         19.7         1656.7
# 1            2908               1173         24.0         1762.0
# 2            1172               1033         20.3         1728.5
# 3            1321                  7         23.5         1647.8
# 4            1004               -230         22.5         1740.4
# ...           ...                ...          ...            ...
# 9874        -2519              -2469         22.9         1524.6
# 9875         -782               -888         20.6         1545.6
# 9876         2416               1877         26.1         1831.9
# 9877          839               1085         24.7         1529.8
# 9878         -927                 58         20.1         1533.9
#
# [9879 rows x 39 columns]

# %%
X = lol_games.drop('blueWins', axis=1)
y = lol_games['blueWins'].values
X
# Out:
#       blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  blueKills  \
# 0                  28                   2               1          9
# 1                  12                   1               0          5
# 2                  15                   0               0          7
# 3                  43                   1               0          4
# 4                  75                   4               0          6
# ...               ...                 ...             ...        ...
# 9874               17                   2               1          7
# 9875               54                   0               0          6
# 9876               23                   1               0          6
# 9877               14                   4               1          2
# 9878               18                   0               1          6
#
#       blueDeaths  blueAssists  blueEliteMonsters  blueDragons  blueHeralds  \
# 0              6           11                  0            0            0
# 1              5            5                  0            0            0
# 2             11            4                  1            1            0
# 3              5            5                  1            0            1
# 4              6            6                  0            0            0
# ...          ...          ...                ...          ...          ...
# 9874           4            5                  1            1            0
# 9875           4            8                  1            1            0
# 9876           7            5                  0            0            0
# 9877           3            3                  1            1            0
# 9878           6            5                  0            0            0
#
#       blueTowersDestroyed  ...  redTowersDestroyed  redTotalGold  redAvgLevel  \
# 0                       0  ...                   0         16567          6.8
# 1                       0  ...                   1         17620          6.8
# 2                       0  ...                   0         17285          6.8
# 3                       0  ...                   0         16478          7.0
# 4                       0  ...                   0         17404          7.0
# ...                   ...  ...                 ...           ...          ...
# 9874                    0  ...                   0         15246          6.8
# 9875                    0  ...                   0         15456          7.0
# 9876                    0  ...                   0         18319          7.4
# 9877                    0  ...                   0         15298          7.2
# 9878                    0  ...                   0         15339          6.8
#
#       redTotalExperience  redTotalMinionsKilled  redTotalJungleMinionsKilled  \
# 0                  17047                    197                           55
# 1                  17438                    240                           52
# 2                  17254                    203                           28
# 3                  17961                    235                           47
# 4                  18313                    225                           67
# ...                  ...                    ...                          ...
# 9874               16498                    229                           34
# 9875               18367                    206                           56
# 9876               19909                    261                           60
# 9877               18314                    247                           40
# 9878               17379                    201                           46
#
#       redGoldDiff  redExperienceDiff  redCSPerMin  redGoldPerMin
# 0            -643                  8         19.7         1656.7
# 1            2908               1173         24.0         1762.0
# 2            1172               1033         20.3         1728.5
# 3            1321                  7         23.5         1647.8
# 4            1004               -230         22.5         1740.4
# ...           ...                ...          ...            ...
# 9874        -2519              -2469         22.9         1524.6
# 9875         -782               -888         20.6         1545.6
# 9876         2416               1877         26.1         1831.9
# 9877          839               1085         24.7         1529.8
# 9878         -927                 58         20.1         1533.9
#
# [9879 rows x 38 columns]

# %%
#Splitting the data into Training Set and Test Set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=0)
X_test
# Out:
#       blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  blueKills  \
# 3535               13                   1               1          5
# 7150               18                   7               1          7
# 9578               12                   1               0          6
# 6882               12                   3               0          3
# 3766               17                   2               1          5
# ...               ...                 ...             ...        ...
# 2515               20                   2               0          4
# 6556               16                   3               1          2
# 4110               10                   2               0          9
# 6198               87                   2               0          2
# 2615               78                   1               1          4
#
#       blueDeaths  blueAssists  blueEliteMonsters  blueDragons  blueHeralds  \
# 3535           7            5                  0            0            0
# 7150           2            5                  0            0            0
# 9578          11            5                  0            0            0
# 6882           9            0                  0            0            0
# 3766           9            5                  0            0            0
# ...          ...          ...                ...          ...          ...
# 2515           6            3                  0            0            0
# 6556           4            4                  0            0            0
# 4110           1           13                  1            0            1
# 6198           4            0                  0            0            0
# 2615          10            7                  0            0            0
#
#       blueTowersDestroyed  ...  redTowersDestroyed  redTotalGold  redAvgLevel  \
# 3535                    0  ...                   0         16463          7.0
# 7150                    0  ...                   0         14788          6.8
# 9578                    0  ...                   0         18363          7.4
# 6882                    0  ...                   0         17543          7.0
# 3766                    0  ...                   0         17000          6.4
# ...                   ...  ...                 ...           ...          ...
# 2515                    0  ...                   0         17148          7.2
# 6556                    0  ...                   0         16060          7.2
# 4110                    0  ...                   0         15077          7.0
# 6198                    0  ...                   0         15553          7.2
# 2615                    0  ...                   0         18619          7.6
#
#       redTotalExperience  redTotalMinionsKilled  redTotalJungleMinionsKilled  \
# 3535               18230                    197                           68
# 7150               16859                    225                           44
# 9578               19694                    206                           64
# 6882               18875                    223                           50
# 3766               16659                    179                           68
# ...                  ...                    ...                          ...
# 2515               18645                    243                           64
# 6556               19262                    227                           63
# 4110               17096                    244                           58
# 6198               18916                    206                           64
# 2615               19898                    238                           59
#
#       redGoldDiff  redExperienceDiff  redCSPerMin  redGoldPerMin
# 3535          887               1878         19.7         1646.3
# 7150        -1496              -1758         22.5         1478.8
# 9578         2082               2125         20.6         1836.3
# 6882         3041               1317         22.3         1754.3
# 3766         1047                193         17.9         1700.0
# ...           ...                ...          ...            ...
# 2515         1630                531         24.3         1714.8
# 6556         1285               1925         22.7         1606.0
# 4110        -2252              -1086         24.4         1507.7
# 6198         1021               1439         20.6         1555.3
# 2615         3584               3248         23.8         1861.9
#
# [2964 rows x 38 columns]

# %% [markdown]
# # Decision Tree

# %%
#Fitting Classifier to Training Set. Create a classifier object here and call it classifierObj
from sklearn.tree import DecisionTreeClassifier
classifierObj = DecisionTreeClassifier(criterion='entropy', random_state=0)
classifierObj.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
#Making predictions on the Test Set
decision_tree_pred = classifierObj.predict(X_test)

# %%
#Evaluating the predictions using a Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, decision_tree_pred)
cm
# Out:
# array([[984, 536],
#        [512, 932]], dtype=int64)

# %%
classifierObj.score(X_test,y_test)
# a single decision tree gets a score of 64.6%
# Out:
# 0.6464237516869096

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
classifierObj = RandomForestClassifier(n_estimators=500, criterion='entropy', max_depth=8, min_samples_leaf=20, random_state=0)
classifierObj.fit(X_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=8, min_samples_leaf=20,
#                        n_estimators=500, random_state=0)

# %%
#Making predictions on the Test Set
random_forest_pred = classifierObj.predict(X_test)

# %%
classifierObj.score(X_test,y_test)
# 72.3%
# Out:
# 0.7230094466936572

# %% [markdown]
# # KNN

# %%
#Normalizing the features
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train_normalized = sc_X.fit_transform(X_train)
X_test_normalized = sc_X.transform(X_test)

# %%
#Fitting Classifier to Training Set. Create a classifier object here and call it classifierObj
from sklearn.neighbors import KNeighborsClassifier
classifierObj = KNeighborsClassifier(n_neighbors=50, p=2, metric='minkowski')
classifierObj.fit(X_train_normalized, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=50)

# %%
#Making predictions on the Test Set
knn_pred = classifierObj.predict(X_test_normalized)

# %%
classifierObj.score(X_test_normalized,y_test)
# 71.5%
# Out:
# 0.7152496626180836

# %% [markdown]
# # Logistic Regression

# %%
#Fitting Logistic Regression to Training Set
from sklearn.linear_model import LogisticRegression
classifierObj = LogisticRegression(random_state=0)
classifierObj.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
classifierObj.coef_
# Out:
# array([[-1.20198661e-03,  1.23056727e-03,  1.02573703e-03,
#          6.73222594e-04, -7.99317327e-04,  1.66659109e-04,
#          3.99708043e-03,  3.93216199e-03,  6.49184399e-05,
#         -1.68860684e-04,  1.07183892e-04, -1.22634785e-04,
#          1.19652205e-05, -1.43744974e-03,  8.70348995e-03,
#          1.88066676e-04,  7.99142099e-05, -1.43744974e-04,
#          1.07183892e-05, -2.79042885e-03, -4.63576639e-04,
#         -1.03248497e-03, -7.99317327e-04,  6.73222594e-04,
#         -1.56518170e-03, -4.32961054e-03, -3.91336184e-03,
#         -4.16248701e-04,  3.96351710e-04, -8.08827849e-05,
#         -8.35560289e-05, -6.79489893e-05,  3.38271858e-03,
#         -3.63133167e-03, -1.88066676e-04, -7.99142099e-05,
#          3.38271858e-04, -8.08827849e-06]])

# %%
#Making predictions on the Test Set
logistic_reg_pred = classifierObj.predict(X_test)

# %%
classifierObj.score(X_test,y_test)
# 72%
# Out:
# 0.7199730094466936

# %% [markdown]
# # Naive Bayes

# %%
#Fitting Classifier to Training Set. Create a classifier object here and call it classifierObj
from sklearn.naive_bayes import GaussianNB
classifierObj = GaussianNB()
classifierObj.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
#Making predictions on the Test Set
naive_bayes_pred = classifierObj.predict(X_test)

# %%
classifierObj.score(X_test,y_test)
# 72.1%
# Out:
# 0.7209851551956815

# %% [markdown]
# # SVM

# %%
#Fitting Classifier to Training Set. Create a classifier object here and call it classifierObj
# can use linear, poly, rbf, sigmoid,or precomputed kernels
from sklearn.svm import SVC
classifierObj = SVC(C=2, kernel='linear')
classifierObj.fit(X_train, y_train)
# Out:
# SVC(C=2, kernel='linear')

# %%
#Making predictions on the Test Set
svm_pred = classifierObj.predict(X_test)

# %%
classifierObj.score(X_test,y_test)
# 72.2%
# Out:
# 0.7223346828609987

# %%
# next: try PCA, LDA, create an ensemble
